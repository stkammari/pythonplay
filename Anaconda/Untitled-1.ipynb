# %%
# %pip install pandas 
# %pip install openpyxl
# Out:
# 478317.34s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.
# 478323.44s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np

# %%
dd = np.empty([2], dtype=int)
print("Matrix a :", dd)
# Out:
# Matrix a : [-549954826522596214 8319505319643358177]

# %%
df = pd.read_excel("/Users/saiteja/Desktop/python/Pythonplay/LOS Data Extract.xlsx")

# %%
df.shape
# Out:
# (2949, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2949 entries, 0 to 2948
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DB Record #              2949 non-null   int64
#  1   Sales Team               2949 non-null   object
#  2   Account                  2949 non-null   object
#  3   Loan Amt                 2949 non-null   float64
#  4   Processor                2949 non-null   object
#  5   Application Date         2949 non-null   datetime64[ns]
#  6   Lock Expiration          2350 non-null   datetime64[ns]
#  7   Appraisal Date Ordered   2302 non-null   datetime64[ns]
#  8   Appraisal Date Received  1804 non-null   datetime64[ns]
#  9   Estimated Fund Date      2932 non-null   datetime64[ns]
#  10  Last Rate Lock Request   2698 non-null   datetime64[ns]
#  11  Apprisal Due Date        2230 non-null   datetime64[ns]
#  12  Month Fund               2949 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# DB Record #                   0
# Sales Team                    0
# Account                       0
# Loan Amt                      0
# Processor                     0
# Application Date              0
# Lock Expiration             599
# Appraisal Date Ordered      647
# Appraisal Date Received    1145
# Estimated Fund Date          17
# Last Rate Lock Request      251
# Apprisal Due Date           719
# Month Fund                    0
# Product                      10
# Loan Status                   0
# LOS System                    0
# Purpose                       1
# Days to Process               0
# % Purchase                    0
# % Refi                        0
# % Construction                0
# % MOD                         0
# % In Process                  0
# % Approval                    0
# % In Origination Review       0
# % In Closing                  0
# Loan #                        0
# Closer                     2311
# P&I                           0
# ...

# %%
df['Appraisal Date Ordered'].fillna(df['Appraisal Date Ordered'].mean , inplace=True)

# %%
df['Appraisal Date Ordered'].isnull().sum()
# Out:
# np.int64(0)
